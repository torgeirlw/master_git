# %%
import numpy as np
import cv2
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot  as  plt

# %%
import torch
from torch import nn
from torchvision import transforms

# %%
image = cv2.imread('img/cow_gray.jpg')
image = np.array(image)
gray_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
image = cv2.imread('img/fjell.jpg')
image = np.array(image)
fjell_gray_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
#def generate_new_im_with_nbh_lin(train_img, nbh_size):
def generate_train_dat(train_img, nbh_size):
    m, n = nbh_size
    
    train_dat = []
    avg = np.mean(train_img)
    train_img = train_img - avg
    for i in range(m, train_img.shape[0]-m):
        for j in range(n, train_img.shape[1]-n):
            neighborhood = train_img[i-m:i,j-n:j+n]
            flat_n = neighborhood.flatten()
            
            dlt = n
            
            train_ij = flat_n[:-dlt]

            train_dat.append(train_ij)
    
    train_dat = np.array(train_dat)
    return train_dat

# %%
# Plan:

#mer bilder, mixture, skrive sgd, basic om NN, loss i generative, 
# Load more pics, sample random neighboorhood to train model

# %%
#ggg= generate_new_im_with_nbh_lin(gray_img, (5,5))
#train_dat1 = generate_train_dat(gray_img, (5,5))
#train_dat2 = generate_train_dat(fjell_gray_img, (5,5))

# %%
#train_dat_full = np.concatenate((train_dat1,train_dat2),axis=0)
#train_dat_full = train_dat_full.astype(np.uint8)
#trans = transforms.ToTensor()
#train_dat = trans(train_dat_full)
#train_dat = train_dat[0]

# %%
train_dat.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-89746bf4b391> in <module>
# ----> 1 train_dat.shape
#
# NameError: name 'train_dat' is not defined

# %%
class MLP(nn.Module):#define neighborhood size
    '''
    Multilayer Perceptron.
    '''
    def __init__(self):
        super().__init__()
        self.layers = nn.Sequential(
        nn.Flatten(),
        nn.Linear(44, 64),
        nn.ReLU(),
        nn.Linear(64, 32),
        nn.ReLU(),
        nn.Linear(32, 64),
        nn.ReLU(),
        nn.Linear(64, 2),#,
        #nn.ReLU()
        #nn.Sigmoid()
        
        )


    def forward(self, x):
        '''Forward pass'''
        out = self.layers(x)
        
        mu = torch.reshape(out[:,0],(out.shape[0],1))
        sig = torch.reshape(torch.exp(out[:,1]),(out.shape[0],1))

        out = torch.cat((mu,sig),dim=1)
        #print(out)
        return out

# %%
#train_dat = torch.from_numpy(train_dat)
#train_dat = torch.from_numpy(train_dat_full)

# %%
torch.manual_seed(1)
np.random.seed(1)

# %%
#train_dat[:,:-1].shape

# %%
train_dat1 = generate_train_dat(gray_img, (5,5))
train_dat2 = generate_train_dat(fjell_gray_img, (5,5))
train_dat_full = np.concatenate((train_dat1,train_dat2),axis=0)
train_dat_full = train_dat_full.astype(np.uint8)
trans = transforms.ToTensor()
train_dat = trans(train_dat_full)
train_dat = train_dat[0]
#train_dat = torch.from_numpy(train_dat_full)

# %%
train_dat
# Out:
# tensor([[0.1098, 0.1137, 0.1176,  ..., 0.1176, 0.1137, 0.1137],
#         [0.1137, 0.1176, 0.1176,  ..., 0.1137, 0.1137, 0.1137],
#         [0.1176, 0.1176, 0.1137,  ..., 0.1137, 0.1137, 0.1176],
#         ...,
#         [0.9686, 0.9725, 0.9765,  ..., 0.9412, 0.9412, 0.9412],
#         [0.9725, 0.9765, 0.9804,  ..., 0.9412, 0.9412, 0.9490],
#         [0.9765, 0.9804, 0.9804,  ..., 0.9412, 0.9490, 0.9490]])

# %%
train_dat
# Out:
# tensor([[0.7725, 0.7725, 0.7725,  ..., 0.7765, 0.7765, 0.7765],
#         [0.7725, 0.7725, 0.7725,  ..., 0.7765, 0.7765, 0.7765],
#         [0.7725, 0.7725, 0.7725,  ..., 0.7765, 0.7765, 0.7765],
#         ...,
#         [0.9686, 0.9725, 0.9765,  ..., 0.9412, 0.9412, 0.9412],
#         [0.9725, 0.9765, 0.9804,  ..., 0.9412, 0.9412, 0.9490],
#         [0.9765, 0.9804, 0.9804,  ..., 0.9412, 0.9490, 0.9490]])

# %%
train_dat.shape
# Out:
# torch.Size([72200, 45])

# %%
mlp = MLP()

# Define the loss function and optimizer
loss_function = nn.GaussianNLLLoss(full=False, reduction='mean')
optimizer = torch.optim.SGD(mlp.parameters(), lr=1e-4)
trainloader = torch.utils.data.DataLoader(train_dat, batch_size=32, shuffle=True)

# %%
trainloader

# %%
epochs = 20 #20
loss_vals = []

# %%
for e in range(epochs): # 5 epochs at maximum
    
    # Print epoch
    print(f'Starting epoch {e+1}')
    
    # Set current loss value
    current_loss = 0.0
    
    for i, data in enumerate(trainloader, 0):
      
      # Get and prepare inputs
        inputs, targets = data[:,:-1], data[:,-1]
        inputs, targets = inputs.float(), targets.float()
        targets = targets.reshape((targets.shape[0], 1))
      
      # Zero the gradients
        optimizer.zero_grad()
      
      # Perform forward pass
        outputs = mlp(inputs)
        mu_s = outputs[:,0]
        sigma_s = outputs[:,1]  #sigma2 
        #sigma_s = torch.exp(outputs[:,1])
        #print(outputs.shape)
      
      # Compute loss
        #loss = loss_function(outputs, targets)
        loss = loss_function(mu_s, targets, sigma_s)
      
      # Perform backward pass
        loss.backward()
      
      # Perform optimization
        optimizer.step()
      
      # Print statistics
        current_loss += loss.item()
        
        if i % 500 == 0:
            print('Loss after mini-batch %5d: %.3f' %
                (i + 1, current_loss / 500))
            current_loss = 0.0

  # Process is complete.
    loss_vals.append(current_loss)
    print('Training process has finished.')
# Out:
# Starting epoch 1
# Loss after mini-batch     1: 0.000
# Loss after mini-batch   501: 0.208
# Loss after mini-batch  1001: 0.163
# Loss after mini-batch  1501: 0.129
# Loss after mini-batch  2001: 0.095
# Training process has finished.
# Starting epoch 2
# Loss after mini-batch     1: 0.000
# Loss after mini-batch   501: 0.051
# Loss after mini-batch  1001: 0.023
# Loss after mini-batch  1501: -0.004
# Loss after mini-batch  2001: -0.030
# Training process has finished.
# Starting epoch 3
# Loss after mini-batch     1: -0.000
# Loss after mini-batch   501: -0.071
# Loss after mini-batch  1001: -0.099
# Loss after mini-batch  1501: -0.127
# Loss after mini-batch  2001: -0.157
# Training process has finished.
# Starting epoch 4
# Loss after mini-batch     1: -0.000
# Loss after mini-batch   501: -0.203
# Loss after mini-batch  1001: -0.236
# Loss after mini-batch  1501: -0.270
# Loss after mini-batch  2001: -0.306
# Training process has finished.
# Starting epoch 5
# Loss after mini-batch     1: -0.001
# Loss after mini-batch   501: -0.367
# Loss after mini-batch  1001: -0.408
# Loss after mini-batch  1501: -0.452
# Loss after mini-batch  2001: -0.501
# Training process has finished.
# Starting epoch 6
# Loss after mini-batch     1: -0.001
# Loss after mini-batch   501: -0.585
# Loss after mini-batch  1001: -0.647
# Loss after mini-batch  1501: -0.707
# Loss after mini-batch  2001: -0.770
# Training process has finished.
# Starting epoch 7
# Loss after mini-batch     1: -0.002
# Loss after mini-batch   501: -0.850
# Loss after mini-batch  1001: -0.897
# Loss after mini-batch  1501: -0.922
# Loss after mini-batch  2001: -0.931
# Training process has finished.
# Starting epoch 8
# Loss after mini-batch     1: -0.002
# Loss after mini-batch   501: -0.965
# Loss after mini-batch  1001: -0.971
# Loss after mini-batch  1501: -0.986
# Loss after mini-batch  2001: -1.000
# Training process has finished.
# Starting epoch 9
# Loss after mini-batch     1: -0.002
# Loss after mini-batch   501: -1.025
# Loss after mini-batch  1001: -1.028
# Loss after mini-batch  1501: -1.044
# Loss after mini-batch  2001: -1.047
# Training process has finished.
# Starting epoch 10
# Loss after mini-batch     1: -0.002
# Loss after mini-batch   501: -1.071
# Loss after mini-batch  1001: -1.068
# Loss after mini-batch  1501: -1.097
# Loss after mini-batch  2001: -1.087
# Training process has finished.
# Starting epoch 11
# Loss after mini-batch     1: -0.003
# Loss after mini-batch   501: -1.114
# Loss after mini-batch  1001: -1.112
# Loss after mini-batch  1501: -1.107
# Loss after mini-batch  2001: -1.129
# Training process has finished.
# Starting epoch 12
# Loss after mini-batch     1: -0.002
# Loss after mini-batch   501: -1.165
# Loss after mini-batch  1001: -1.149
# Loss after mini-batch  1501: -1.139
# Loss after mini-batch  2001: -1.139
# Training process has finished.
# Starting epoch 13
# Loss after mini-batch     1: -0.003
# Loss after mini-batch   501: -1.160
# Loss after mini-batch  1001: -1.182
# Loss after mini-batch  1501: -1.182
# Loss after mini-batch  2001: -1.205
# Training process has finished.
# Starting epoch 14
# Loss after mini-batch     1: -0.002
# Loss after mini-batch   501: -1.219
# Loss after mini-batch  1001: -1.213
# Loss after mini-batch  1501: -1.223
# Loss after mini-batch  2001: -1.221
# Training process has finished.
# Starting epoch 15
# Loss after mini-batch     1: -0.001
# Loss after mini-batch   501: -1.231
# Loss after mini-batch  1001: -1.234
# Loss after mini-batch  1501: -1.230
# Loss after mini-batch  2001: -1.256
# Training process has finished.
# Starting epoch 16
# Loss after mini-batch     1: -0.003
# Loss after mini-batch   501: -1.218
# Loss after mini-batch  1001: -1.264
# Loss after mini-batch  1501: -1.257
# Loss after mini-batch  2001: -1.246
# Training process has finished.
# Starting epoch 17
# Loss after mini-batch     1: -0.003
# Loss after mini-batch   501: -1.271
# Loss after mini-batch  1001: -1.235
# Loss after mini-batch  1501: -1.273
# Loss after mini-batch  2001: -1.275
# Training process has finished.
# Starting epoch 18
# Loss after mini-batch     1: -0.003
# Loss after mini-batch   501: -1.245
# Loss after mini-batch  1001: -1.288
# Loss after mini-batch  1501: -1.283
# Loss after mini-batch  2001: -1.268
# Training process has finished.
# Starting epoch 19
# Loss after mini-batch     1: -0.003
# Loss after mini-batch   501: -1.267
# Loss after mini-batch  1001: -1.306
# Loss after mini-batch  1501: -1.242
# Loss after mini-batch  2001: -1.302
# Training process has finished.
# Starting epoch 20
# Loss after mini-batch     1: -0.003
# Loss after mini-batch   501: -1.284
# Loss after mini-batch  1001: -1.279
# Loss after mini-batch  1501: -1.311
# Loss after mini-batch  2001: -1.282
# Training process has finished.

# %%
print(torch.__version__)
# Out:
# 1.8.1

# %%
plt.plot(range(len(loss_vals)),loss_vals)
plt.title('loss')
# Out:
# Text(0.5, 1.0, 'loss')

# %%
def gen_im(model, im_size, nbh_size):
    m, n = nbh_size
    
    #new_im = np.zeros(im_size)
    #new_im = torch.zeros(im_size)
    #new_im = torch.full(im_size, 100.0)
    #new_im = torch.randint(low=50, high=150, size=im_size,dtype=torch.float)
    
    #new_im = torch.rand(im_size) # prøv med 0.5
    new_im = torch.full(im_size,0.5)
    
    #neighborhood = train_img[i-m:i,j-n:j+n-1]
    #flat_n = neighborhood.flatten()
    
    
    for i in range(m, new_im.shape[0]-m):
        for j in range(n, new_im.shape[1]-n):
            
            neighborhood = new_im[i-m:i,j-n:j+n]
            flat_n = neighborhood.flatten()
            
            dlt = n
            
            nbh_ij = flat_n[:-(dlt+1)]
            #print(nbh_ij.shape)
            output = model(torch.reshape(nbh_ij,(1,44)))
            #print(output)
            sample = np.random.normal(output.detach().numpy()[0,0],np.sqrt(np.abs(output.detach().numpy()[0,1])))
            
            
            
            new_im[i,j] = sample
    
    return(new_im)

# %%
generatted_im = gen_im(mlp, (200,200), (5,5))

# %%
#prøv å generere med ku bilde og fjell og et annet bilde, output mu og sigma(sd).
#prøv å starte med ku og generere bilde.
#prøv å trene med imagenet med gpu.
#prøv med mindre naboskap

# %%
generatted_im = np.clip(generatted_im, 0, 1)

# %%
plt.imshow(generatted_im,cmap='gray')
plt.colorbar()

# %%
torch.min(generatted_im)
# Out:
# tensor(0.)

# %%
trans = transforms.ToTensor()
cow_im = trans(gray_img)
cow_im = cow_im[0]

# %%
cow_im.shape
# Out:
# torch.Size([200, 200])

# %%
def gen_cow_mu_sigma(model, im_size, nbh_size, cow_im):
    m, n = nbh_size
    
    #new_im = torch.rand(im_size)# prøv med 0.5
    cow_im = cow_im
    
    #cow_mu = torch.zeros(im_size)
    #cow_sigma = torch.zeros(im_size)  #sd
    
    cow_mu = np.zeros(im_size)
    cow_sigma = np.zeros(im_size)  #sd
    #neighborhood = train_img[i-m:i,j-n:j+n-1]
    #flat_n = neighborhood.flatten()
    
    
    for i in range(m, cow_im.shape[0]-m):
        for j in range(n, cow_im.shape[1]-n):
            
            #neighborhood = new_im[i-m:i,j-n:j+n-1]
            neighborhood = cow_im[i-m:i,j-n:j+n] #feil
            flat_n = neighborhood.flatten()
            
            dlt = n #feil
            #print(flat_n.shape)
            nbh_ij = flat_n[:-(dlt+1)]
            #print(nbh_ij.shape)
            output = model(torch.reshape(nbh_ij,(1,44)))
            #print(output)
            cow_mu[i,j] = output.detach().numpy()[0,0]
            cow_sigma[i,j] = np.sqrt(np.abs(output.detach().numpy()[0,1]))
            
            
            #sample = np.random.normal(output.detach().numpy()[0,0],np.sqrt(np.abs(output.detach().numpy()[0,1])))
            
            
            
            #new_im[i,j] = sample
    
    return cow_mu, cow_sigma

# %%
cow_mu, cow_sigma = gen_cow_mu_sigma(mlp, (200,200), (5,5), cow_im)

# %%
plt.imshow(cow_mu,cmap='gray')
plt.colorbar()

# %%
plt.imshow(cow_sigma,cmap='gray')
plt.colorbar()

# %%
plt.imshow(cow_im,cmap='gray')
plt.colorbar()

# %%
koala = cv2.imread('img/KoalaBear.jpg')
koala = np.array(koala)
koala = cv2.cvtColor(koala, cv2.COLOR_BGR2GRAY)

# %%
koala_im = trans(koala)
koala_im = koala_im[0]

# %%
koala_mu, koala_sigma = gen_cow_mu_sigma(mlp, (200,200), (5,5), koala_im)

# %%
#koala_mu[30]

# %%
#koala_im[30]

# %%
plt.imshow(koala_mu,cmap='gray')
plt.colorbar()

# %%
plt.imshow(koala_sigma,cmap='gray')
plt.colorbar()

# %%
plt.imshow(koala_im,cmap='gray')
plt.colorbar()

# %%
def gen_cow(model, im_size, nbh_size, cow_im):
    m, n = nbh_size
    
    #new_im = np.zeros(im_size)
    #new_im = torch.zeros(im_size)
    #new_im = torch.full(im_size, 100.0)
    #new_im = torch.randint(low=50, high=150, size=im_size,dtype=torch.float)
    
    #new_im = torch.rand(im_size) # prøv med 0.5
    new_im = cow_im
    
    #neighborhood = train_img[i-m:i,j-n:j+n-1]
    #flat_n = neighborhood.flatten()
    
    
    for i in range(m, new_im.shape[0]-m):
        for j in range(n, new_im.shape[1]-n):
            
            neighborhood = new_im[i-m:i,j-n:j+n]
            flat_n = neighborhood.flatten()
            
            dlt = n
            
            nbh_ij = flat_n[:-(dlt+1)]
            #print(nbh_ij.shape)
            output = model(torch.reshape(nbh_ij,(1,44)))
            #print(output)
            sample = np.random.normal(output.detach().numpy()[0,0],np.sqrt(np.abs(output.detach().numpy()[0,1])))
            
            
            
            new_im[i,j] = sample
    
    return(new_im)

# %%
new_cow_im = gen_cow(mlp, (200,200), (5,5), koala_im)

# %%
plt.imshow(new_cow_im,cmap='gray')
plt.colorbar()

# %%
def nbh_test(im_size, nbh_size):
    new_im = np.zeros(im_size)
    m,n = nbh_size
    for i in range(m, new_im.shape[0]-m):
        for j in range(n, new_im.shape[1]-n):
            neighborhood = new_im[i-m:i,j-n:j+n]
            flat_n = neighborhood.flatten()
            
            dlt = n
            print(flat_n.shape)
            nbh_ij = flat_n[:-(dlt+1)]
            print(nbh_ij.shape)

# %%
nbh_test((200,200),(5,5))
# Out:
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# ...
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)
# (50,)
# (44,)

# %%
mlp(torch.ones((1,42))).detach().numpy()
# Out:
# array([[nan, nan]], dtype=float32)

# %%
np.log(0.00001)
# Out:
# -11.512925464970229
